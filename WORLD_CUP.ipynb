# %% [markdown]
# . ---THIS IS A WORLD-CUP DATA SET AND USING THIS DATA SET DISCUSS SOME FUNCTION IN PYTHON FOR DATA REPRESENTATION AND VISUALIZATION --- .

# %%
#IMPORT THE LIBRARY FOR INCLUDING FUNCTION 
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# PRINTING THE FULL DATA SET 
data=pd.read_csv("D:/VAC-MATIRIAL-EXAMPLES/WorldCupMatches.csv")
data
# Out:
#      Year              Datetime                     Stage  \
# 0    1930  13 Jul 1930 - 15:00                    Group 1
# 1    1930  13 Jul 1930 - 15:00                    Group 4
# 2    1930  14 Jul 1930 - 12:45                    Group 2
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France                4
# 1         Parque Central      Montevideo             USA                3
# ...

# %%
#PRINTING THE TOTAL NUMBER OF ROWS AND COLUMN 
print(data.shape)
# Out:
# (852, 20)

# %%
#PRINTING FIRST 5(0-4) ROWS BYDEFAULT ...
data.head()
#PRINTING FIRST 10 ROWS AS PER PASSING THE PARAMETER...
data.head(11)
# Out:
#     Year              Datetime    Stage             Stadium         City  \
# 0   1930  13 Jul 1930 - 15:00   Group 1             Pocitos  Montevideo
# 1   1930  13 Jul 1930 - 15:00   Group 4      Parque Central  Montevideo
# 2   1930  14 Jul 1930 - 12:45   Group 2      Parque Central  Montevideo
# 3   1930  14 Jul 1930 - 14:50   Group 3             Pocitos  Montevideo
# 4   1930  15 Jul 1930 - 16:00   Group 1      Parque Central  Montevideo
# 5   1930  16 Jul 1930 - 14:45   Group 1      Parque Central  Montevideo
# 6   1930  17 Jul 1930 - 12:45   Group 2      Parque Central  Montevideo
# 7   1930  17 Jul 1930 - 14:45   Group 4      Parque Central  Montevideo
# 8   1930  18 Jul 1930 - 14:30   Group 3  Estadio Centenario  Montevideo
# 9   1930  19 Jul 1930 - 12:50   Group 1  Estadio Centenario  Montevideo
# 10  1930  19 Jul 1930 - 15:00   Group 1  Estadio Centenario  Montevideo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# ...

# %%
#PRINTING LAST 5(0-4) ROWS BYDEFAULT ...
data.tail()
##PRINTING LAST 10 ROWS AS PER PASSING THE PARAMETER...
data.tail(11)
# Out:
#      Year              Datetime                     Stage  \
# 841  2014  30 Jun 2014 - 17:00                Round of 16
# 842  2014  01 Jul 2014 - 13:00                Round of 16
# 843  2014  01 Jul 2014 - 17:00                Round of 16
# 844  2014  04 Jul 2014 - 13:00             Quarter-finals
# 845  2014  04 Jul 2014 - 17:00             Quarter-finals
# 846  2014  05 Jul 2014 - 13:00             Quarter-finals
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 841    Estadio Beira-Rio    Porto Alegre         Germany                2
# 842   Arena de Sao Paulo       Sao Paulo       Argentina                1
# ...

# %%
#PRINTING A PRTICULAR ROW TO ANOTHER PARTICULAR ROW USING SLICING 
data[2:11] # [STARTING ROW : ENDING ROW-1]
# Out:
#     Year              Datetime    Stage             Stadium         City  \
# 2   1930  14 Jul 1930 - 12:45   Group 2      Parque Central  Montevideo
# 3   1930  14 Jul 1930 - 14:50   Group 3             Pocitos  Montevideo
# 4   1930  15 Jul 1930 - 16:00   Group 1      Parque Central  Montevideo
# 5   1930  16 Jul 1930 - 14:45   Group 1      Parque Central  Montevideo
# 6   1930  17 Jul 1930 - 12:45   Group 2      Parque Central  Montevideo
# 7   1930  17 Jul 1930 - 14:45   Group 4      Parque Central  Montevideo
# 8   1930  18 Jul 1930 - 14:30   Group 3  Estadio Centenario  Montevideo
# 9   1930  19 Jul 1930 - 12:50   Group 1  Estadio Centenario  Montevideo
# 10  1930  19 Jul 1930 - 15:00   Group 1  Estadio Centenario  Montevideo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 2      Yugoslavia                2                1         Brazil
# 3         Romania                3                1           Peru
# ...

# %%
#SHOW ALL THE COLUMNS INFORMATION IN ROW-MAJOR ORDER...
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    int64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    int64
#  7   Away Team Goals       852 non-null    int64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    int64
#  12  Half-time Away Goals  852 non-null    int64
#  13  Referee               852 non-null    object
#  14  Assistant 1           852 non-null    object
# ...

# %%
#DESCRIPTION ABOUT THE DATA SET
data.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     852.000000
# mean   1985.089202         1.811033         1.022300   45059.248826
# std      22.448825         1.610255         1.087573   23558.463162
# min    1930.000000         0.000000         0.000000     200.000000
# 25%    1970.000000         1.000000         0.000000   29947.500000
# 50%    1990.000000         2.000000         1.000000   41441.500000
# 75%    2002.000000         3.000000         2.000000   61361.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
#INDICATE WHERE NULL VALUES ARE PRESENT
data.isnull()
# Out:
#       Year  Datetime  Stage  Stadium   City  Home Team Name  Home Team Goals  \
# 0    False     False  False    False  False           False            False
# 1    False     False  False    False  False           False            False
# 2    False     False  False    False  False           False            False
# 3    False     False  False    False  False           False            False
# 4    False     False  False    False  False           False            False
# ..     ...       ...    ...      ...    ...             ...              ...
# 847  False     False  False    False  False           False            False
# 848  False     False  False    False  False           False            False
# 849  False     False  False    False  False           False            False
# 850  False     False  False    False  False           False            False
# 851  False     False  False    False  False           False            False
#
# ...

# %%
#PRINTING THE ALL COLUMNS ...
data.columns.values
# Out:
# array(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype=object)

# %%
#STATISTICAL FUNCTION FOR CALCULATING AVG
a=data['Home Team Goals'].mean()
print(a)

b=data['MatchID'].median()
print(b)

c=data['RoundID'].mode()
print(c)
# Out:
# 1.8110328638497653
# 2191.0
# 0        1014
# 1      249722
# 2      255931
# 3    43950100
# 4    97410100
# Name: RoundID, dtype: int64

# %%
#PRINTING A PARTICULAR COLUMN FROM THE DATA SET
data[['City']].shape
data[['City']]
# Out:
#                 City
# 0        Montevideo
# 1        Montevideo
# 2        Montevideo
# 3        Montevideo
# 4        Montevideo
# ..               ...
# 847        Salvador
# 848  Belo Horizonte
# 849       Sao Paulo
# 850        Brasilia
# 851  Rio De Janeiro
#
# [852 rows x 1 columns]

# %%
#COUNTING VALUES FROM PARTICULAR COLUMN
data['Home Team Goals'].value_counts()
# Out:
# Home Team Goals
# 1     246
# 2     205
# 0     177
# 3     116
# 4      59
# 5      17
# 6      17
# 7       8
# 8       4
# 9       2
# 10      1
# Name: count, dtype: int64

# %%
#SORTING DATA SET ACCRODING TO THE DATA
data.sort_values(by='Home Team Goals')
# Out:
#      Year              Datetime                     Stage  \
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 818  2014  26 Jun 2014 - 17:00                    Group H
# 825  2014  04 Jul 2014 - 13:00             Quarter-finals
# 827  2014  12 Jul 2014 - 17:00   Play-off for third place
# 829  2014  09 Jul 2014 - 17:00                Semi-finals
# ..    ...                   ...                       ...
# 66   1950  02 Jul 1950 - 15:00                    Group 4
# 46   1938  12 Jun 1938 - 17:00             Quarter-finals
# 80   1954  17 Jun 1954 - 18:00                    Group 2
# 243  1974  18 Jun 1974 - 19:30                    Group 2
# 312  1982  15 Jun 1982 - 21:00                    Group 3
#
#                  Stadium             City  Home Team Name  Home Team Goals  \
# 850     Estadio Nacional        Brasilia           Brazil                0
# 818   Arena de Sao Paulo       Sao Paulo   Korea Republic                0
# ...

# %%
data.fillna(200,inplace=True)#FILL THE NULL POSITION 200 IN THOSE PLACE ...
dt=pd.DataFrame(data)
dt.describe()
print(data.to_string())
# Out:
#      Year               Datetime                     Stage                                             Stadium                                City              Home Team Name  Home Team Goals  Away Team Goals              Away Team Name                                 Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals                               Referee                           Assistant 1                           Assistant 2   RoundID    MatchID Home Team Initials Away Team Initials
# ...

# %%
#FIND OUT MAX AND MIN  
data['Half-time Home Goals'].max()
data['Half-time Home Goals'].min()
# Out:
# np.float64(0.0)

# %%
sns.pairplot(data)

# %%
data.plot(kind='bar',x='Year',y='Home Team Goals')
# Out:
# <Axes: xlabel='Year'>

# %%
data.plot(kind='hist',x='Year',y='Home Team Goals')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot(kind='hexbin',x='Year',y='Home Team Goals')
# Out:
# <Axes: xlabel='Year', ylabel='Home Team Goals'>

# %%
data.plot(kind='scatter',x='Year',y='Home Team Goals')
# Out:
# <Axes: xlabel='Year', ylabel='Home Team Goals'>

# %%
data.plot(kind='box',x='Year',y='Home Team Goals')
# Out:
# <Axes: >

# %%
sns.pairplot(data,hue='Home Team Goals')
